# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
underlying = pd.read_csv("data/spx_minute_level_data_jan_mar_2024.csv")

end_date = datetime(2024, 3, 30)

# %%
options : pd.DataFrame = pd.read_csv("data/cleaned_options_data.csv")
options["day"] = pd.to_datetime(options["ts_recv"].apply(lambda x: x.split("T")[0]))


options['datetime'] = pd.to_datetime(options['ts_recv'], format="%Y-%m-%dT%H:%M:%S.%fZ", utc=True).dt.tz_convert('US/Eastern')
options['symbol_data'] = options['symbol'].str.split('   ', expand=True)[1]

options['expiration_date'] = pd.to_datetime(options['symbol_data'].str[:6], format="%y%m%d")
options['type'] = options['symbol_data'].str[6]
options['strike'] = options['symbol_data'].str[7:].astype(float) / 1000

processed_options = options.drop(columns=['symbol_data'])

# %%
processed_options.sort_values(by=['day', 'strike'])

current_date = datetime(2024, 1, 3)
processed_options = processed_options.loc[processed_options['expiration_date'] <= end_date, :] # only include options that expire before the end date

# %%
processed_options.loc[processed_options['day'] == current_date, :]
# Out:
#                               ts_recv  instrument_id  bid_px_00  ask_px_00  \
# 22556  2024-01-03T14:30:02.202022762Z      587211485       80.0      80.80
# 22557  2024-01-03T14:30:02.202026374Z      587244347       45.5      46.10
# 22558  2024-01-03T14:30:02.202026374Z      587244322       54.7      55.40
# 22559  2024-01-03T14:30:02.202943645Z      587244322       54.7      55.40
# 22560  2024-01-03T14:30:02.202947933Z      587219703       14.0      14.30
# ...                               ...            ...        ...        ...
# 43958  2024-01-03T21:48:25.984638748Z      587228724       14.8      15.50
# 43959  2024-01-03T21:48:25.984643781Z      587228724       14.8      15.50
# 43960  2024-01-03T21:48:25.984643781Z      587203991       13.3      14.00
# 43961  2024-01-03T21:48:25.984648724Z      587203991       13.3      14.00
# 43962  2024-01-03T21:54:31.192573950Z      587211464        2.0       2.25
#
#        bid_sz_00  ask_sz_00                 symbol        day  \
# 22556         64         30  SPX   240315P04700000 2024-01-03
# 22557         45        152  SPX   240315P04550000 2024-01-03
# 22558         90         95  SPX   240315P04600000 2024-01-03
# 22559         90         95  SPX   240315P04600000 2024-01-03
# 22560        761        467  SPX   240315P04200000 2024-01-03
# ...          ...        ...                    ...        ...
# 43958        111        111  SPX   240119P04620000 2024-01-03
# 43959        111        111  SPX   240119P04620000 2024-01-03
# 43960        118        123  SPX   240119P04610000 2024-01-03
# 43961        118        123  SPX   240119P04610000 2024-01-03
# 43962       1978        406  SPX   240315P03325000 2024-01-03
#
#                                  datetime expiration_date type  strike
# 22556 2024-01-03 09:30:02.202022762-05:00      2024-03-15    P  4700.0
# 22557 2024-01-03 09:30:02.202026374-05:00      2024-03-15    P  4550.0
# 22558 2024-01-03 09:30:02.202026374-05:00      2024-03-15    P  4600.0
# 22559 2024-01-03 09:30:02.202943645-05:00      2024-03-15    P  4600.0
# 22560 2024-01-03 09:30:02.202947933-05:00      2024-03-15    P  4200.0
# ...                                   ...             ...  ...     ...
# 43958 2024-01-03 16:48:25.984638748-05:00      2024-01-19    P  4620.0
# 43959 2024-01-03 16:48:25.984643781-05:00      2024-01-19    P  4620.0
# 43960 2024-01-03 16:48:25.984643781-05:00      2024-01-19    P  4610.0
# 43961 2024-01-03 16:48:25.984648724-05:00      2024-01-19    P  4610.0
# 43962 2024-01-03 16:54:31.192573950-05:00      2024-03-15    P  3325.0
#
# [13571 rows x 12 columns]
